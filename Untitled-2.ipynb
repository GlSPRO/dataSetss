# %% [markdown]
# Цель: реализовать базовый анализ датасета:
# Датасеты не должны повторяться
# Вывести весь датасет и опишите его
# Вывести размерноть массива
# Вывести наименование всех колонок, написать что они означают в вашем датасете
# Вывести все уникальные значения
# Отсортировать по определенным параметрам
# Удалить ненужные столбцы или строчки
# Заменить определенные значения в датасете (например, пустые)
# Удалить дубликаты
# Провести анализ с помощью функций info
# Провести анализ с помощью функций describe
# Провести выборку данных по строкам и столбцам с помощью loc
# Сохранить новый датасет
# Сделать вывод по каждому пункту и описать все

# %%
import pandas as pd

spotify_songs = pd.read_csv("spotify_songs.csv")

spotify_songs
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
spotify_songs.shape
# Out:
# (32833, 23)

# %% [markdown]
# размерность массива

# %%
spotify_songs.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %% [markdown]
# вывели список всех колонок

# %%
spotify_songs["track_id"].unique()
# Out:
# array(['6f807x0ima9a1j3VPbc7VN', '0r7CVbZTWZgbTCYdfa2P31',
#        '1z1Hg7Vb0AhHDiEmnDE79l', ..., '7ImMqPP3Q1yfUHvsdn7wEo',
#        '2m69mhnfQ1Oq6lGtXuYhgX', '29zWqhca3zt5NsckZqDf6c'], dtype=object)

# %%
spotify_songs["track_name"].unique()
# Out:
# array(["I Don't Care (with Justin Bieber) - Loud Luxury Remix",
#        'Memories - Dillon Francis Remix',
#        'All the Time - Don Diablo Remix', ...,
#        'Sweet Surrender - Radio Edit', 'Only For You - Maor Levi Remix',
#        'Typhoon - Original Mix'], dtype=object)

# %%
spotify_songs["track_artist"].unique()
# Out:
# array(['Ed Sheeran', 'Maroon 5', 'Zara Larsson', ...,
#        'Ferry Corsten feat. Jenny Wahlstrom', 'Tegan and Sara', 'Mat Zo'],
#       dtype=object)

# %%
spotify_songs["track_popularity"].unique()
# Out:
# array([ 66,  67,  70,  60,  69,  62,  68,  58,  63,  65,  35,  64,   8,
#         30,  56,  55,  59,  87,  83,  61,  57,  53,  34,  74,  46,  52,
#         45,  51,  48,  39,  71,  81,  85,  76,  75,  73,  79,  16,  84,
#         37,  36,  72,  77,  82,  41,   5,  24,  18,  47,  80,  96,  86,
#         19,  27,  43,  91,  42,  21,  54,   9,  23,  40,   2,  11,  50,
#         10,  49,   6,  25,  95,   1,   4,  28,  29,  38,  17,  31,  26,
#         32,  12,  44,   7,   0,  13,  78,  88,  94,  22,  98,  97,  90,
#         93,  92,   3,  33,  20,  14,  15,  89, 100,  99], dtype=int64)

# %%
spotify_songs["track_album_id"].unique()
# Out:
# array(['2oCs0DGTsRO98Gh5ZSl2Cx', '63rPSO264uRjW1X5E6cWv6',
#        '1HoSmj2eLcsrR0vE9gThr4', ..., '0ltWNSY9JgxoIZO4VzuCa6',
#        '1fGrOkHnHJcStl14zNx8Jy', '0X3mUOm6MhxR7PzxG95rAo'], dtype=object)

# %%
spotify_songs["track_album_name"].unique()
# Out:
# array(["I Don't Care (with Justin Bieber) [Loud Luxury Remix]",
#        'Memories (Dillon Francis Remix)',
#        'All the Time (Don Diablo Remix)', ...,
#        'Sweet Surrender (Radio Edit)', 'Only For You (Remixes)',
#        'Typhoon/Storm'], dtype=object)

# %%
spotify_songs["track_album_release_date"].unique()
# Out:
# array(['2019-06-14', '2019-12-13', '2019-07-05', ..., '2012-02-06',
#        '2012-11-11', '2014-04-18'], dtype=object)

# %%
spotify_songs["playlist_name"].unique()
# Out:
# array(['Pop Remix', 'Dance Pop', 'Dance Room', 'Cardio', 'Dance Pop Hits',
#        'Pop Warmup 130 BPM', 'Dance Pop: Japan', 'K-Party Dance Mix',
#        'Dance Pop Tunes', 'Pop / Dance', 'Todo Éxitos', '90s Dance Hits',
#        'Christian Dance Party', 'Pop Dance Hits',
#        'Best of 2019 Dance Pop: Japan',
#        'Ultimate Indie Presents... Best Indie Tracks of the 2010s',
#        'TUNES DANCE AND POP',
#        'Pop Inglés (2020 - 2010s)💙 Música En Inglés 2010s',
#        'ELETRIC POP & DANCE',
#        'Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop',
#        'The Sound of Post-Teen Pop', 'Post teen pop',
#        'post-teen alternative, indie, pop (large variety)',
#        'Pop Punk | Post-Hardcore', 'Post pop teen',
#        'Intro to Post-Teen Pop', '🤩🤪Post Teen Pop🤪🤩',
#        'Someone You Loved Lewis Capaldi (Pop Music Mix)',
#        "Dr. Q's Prescription Playlist💊", 'a taste of the mainstream',
# ...

# %%
spotify_songs["playlist_id"].unique()
# Out:
# array(['37i9dQZF1DXcZDD7cfEKhW', '37i9dQZF1DWZQaaqNMbbXa',
#        '37i9dQZF1DX2ENAPP1Tyed', '37i9dQZF1DWSJHnPb1f0X3',
#        '37i9dQZF1DX6pH08wMhkaI', '37i9dQZF1DX3PIAZMcbo2T',
#        '37i9dQZF1DXahYFr91pFvG', '37i9dQZF1DX4RDXswvP6Mj',
#        '0B2HdP15IucgE0vk3sluJR', '4SdfG4cPG3skmTiQLozZGh',
#        '6mXh8CUBMBsBUu88a4eAQV', '2ji5tRQVfnhaX1w9FhmSzk',
#        '50cXvxgMGrvoUeLhkzCyIO', '37i9dQZF1DWUUPO0Sbx2CM',
#        '7eERKCkgNKCCx5GYdeMIZf', '37i9dQZF1DXdOtZGKonFlM',
#        '37i9dQZF1DWTHM4kX49UKs', '3arpkhoRWXEYbdCpVAIrRR',
#        '4QAzO1Z92yqqD6Mf3mOANu', '7316uT3vVzTidCI8cinBUv',
#        '46Cl6dmeiylK6TRGXr7hHe', '10FCW9lj0NdeoYI5VVvVtY',
#        '7jQHOrErpLMStcUUSavQWR', '1y42gwI5cuwjBslPyQNfqb',
#        '1YgWQAs1s77NzieIH4ARKn', '222nc9tKxKhfZ2GBrOpwH3',
#        '6o6MNYZqHSkMAKcCHPNu7K', '6IT8LGpwLw3Pt2XnVUBN7j',
#        '6IErGHjBfhey8URq0mFnPi', '6jAPdgY9XmxC9cgkXAVmVv',
#        '4gbXqmZDUFHqlaYjf4uVyS', '2ltt5ouiEO301o2jbxn30d',
# ...

# %%
spotify_songs["playlist_genre"].unique()
# Out:
# array(['pop', 'rap', 'rock', 'latin', 'r&b', 'edm'], dtype=object)

# %%
spotify_songs["playlist_subgenre"].unique()
# Out:
# array(['dance pop', 'post-teen pop', 'electropop', 'indie poptimism',
#        'hip hop', 'southern hip hop', 'gangster rap', 'trap',
#        'album rock', 'classic rock', 'permanent wave', 'hard rock',
#        'tropical', 'latin pop', 'reggaeton', 'latin hip hop',
#        'urban contemporary', 'hip pop', 'new jack swing', 'neo soul',
#        'electro house', 'big room', 'pop edm',
#        'progressive electro house'], dtype=object)

# %%
spotify_songs["danceability"].unique()
# Out:
# array([0.748 , 0.726 , 0.675 , 0.718 , 0.65  , 0.449 , 0.542 , 0.594 ,
#        0.642 , 0.679 , 0.437 , 0.744 , 0.572 , 0.69  , 0.805 , 0.694 ,
#        0.678 , 0.746 , 0.467 , 0.708 , 0.684 , 0.732 , 0.62  , 0.682 ,
#        0.663 , 0.625 , 0.641 , 0.702 , 0.723 , 0.742 , 0.716 , 0.816 ,
#        0.633 , 0.563 , 0.728 , 0.846 , 0.693 , 0.67  , 0.755 , 0.622 ,
#        0.789 , 0.64  , 0.609 , 0.75  , 0.535 , 0.766 , 0.649 , 0.588 ,
#        0.355 , 0.735 , 0.752 , 0.607 , 0.714 , 0.775 , 0.814 , 0.784 ,
#        0.367 , 0.591 , 0.59  , 0.791 , 0.564 , 0.669 , 0.77  , 0.513 ,
#        0.72  , 0.294 , 0.665 , 0.46  , 0.362 , 0.686 , 0.618 , 0.661 ,
#        0.571 , 0.652 , 0.706 , 0.404 , 0.876 , 0.802 , 0.906 , 0.753 ,
#        0.672 , 0.581 , 0.643 , 0.674 , 0.691 , 0.653 , 0.734 , 0.55  ,
#        0.703 , 0.44  , 0.547 , 0.673 , 0.699 , 0.647 , 0.655 , 0.79  ,
#        0.611 , 0.619 , 0.575 , 0.768 , 0.767 , 0.466 , 0.434 , 0.837 ,
# ...

# %%
spotify_songs["energy"].unique()
# Out:
# array([9.16e-01, 8.15e-01, 9.31e-01, 9.30e-01, 8.33e-01, 9.19e-01,
#        8.56e-01, 9.03e-01, 9.35e-01, 8.18e-01, 9.23e-01, 7.74e-01,
#        7.26e-01, 9.15e-01, 7.80e-01, 8.35e-01, 9.01e-01, 7.47e-01,
#        5.57e-01, 8.21e-01, 9.34e-01, 9.13e-01, 8.50e-01, 8.89e-01,
#        7.60e-01, 8.51e-01, 9.05e-01, 9.38e-01, 9.09e-01, 8.69e-01,
#        8.14e-01, 8.37e-01, 8.64e-01, 8.31e-01, 8.54e-01, 8.10e-01,
#        7.73e-01, 6.78e-01, 9.28e-01, 4.53e-01, 8.59e-01, 8.93e-01,
#        8.38e-01, 7.64e-01, 9.92e-01, 9.56e-01, 7.71e-01, 6.97e-01,
#        7.89e-01, 8.40e-01, 5.00e-01, 9.55e-01, 9.95e-01, 7.86e-01,
#        8.01e-01, 8.62e-01, 8.67e-01, 7.79e-01, 7.83e-01, 8.30e-01,
#        7.02e-01, 6.42e-01, 5.65e-01, 8.82e-01, 7.88e-01, 8.58e-01,
#        5.05e-01, 7.99e-01, 8.00e-01, 9.21e-01, 6.60e-01, 6.99e-01,
#        7.25e-01, 7.52e-01, 7.05e-01, 8.98e-01, 8.55e-01, 8.06e-01,
#        6.45e-01, 8.32e-01, 6.57e-01, 6.74e-01, 5.94e-01, 8.81e-01,
# ...

# %%
spotify_songs["key"].unique()
# Out:
# array([ 6, 11,  1,  7,  8,  5,  4,  2,  0, 10,  9,  3], dtype=int64)

# %%
spotify_songs["loudness"].unique()
# Out:
# array([-2.634, -4.969, -3.432, ..., -3.312, -0.378, -1.814])

# %%
spotify_songs["mode"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
spotify_songs["speechiness"].unique()
# Out:
# array([0.0583, 0.0373, 0.0742, ..., 0.0231, 0.624 , 0.578 ])

# %%
spotify_songs["acousticness"].unique()
# Out:
# array([1.02e-01, 7.24e-02, 7.94e-02, ..., 6.26e-04, 4.77e-05, 4.34e-04])

# %%
spotify_songs["instrumentalness"].unique()
# Out:
# array([0.00e+00, 4.21e-03, 2.33e-05, ..., 8.05e-04, 4.67e-05, 8.35e-03])

# %%
spotify_songs["liveness"].unique()
# Out:
# array([0.0653, 0.357 , 0.11  , ..., 0.0323, 0.74  , 0.787 ])

# %%
spotify_songs["valence"].unique()
# Out:
# array([0.518 , 0.693 , 0.613 , ..., 0.0639, 0.05  , 0.0927])

# %%
spotify_songs["tempo"].unique()
# Out:
# array([122.036,  99.972, 124.008, ..., 132.048, 112.028, 128.17 ])

# %%
spotify_songs["duration_ms"].unique()
# Out:
# array([194754, 162600, 176616, ..., 353120, 210112, 367432], dtype=int64)

# %% [markdown]
# 4. Вывели все уникальные значения.

# %%
spotify_songs.sort_values(by='tempo')
# Out:
#                      track_id                                    track_name  \
# 11363  51w6nRCU68klqNfYaaVP2j                         Hi, How're You Doin'?
# 1204   6xPVnZ5WcK9sh9FyYIkiW3                                       Knowing
# 13764  3gIBSlXYIN1mru35l4LWPB             Still Crazy After All These Years
# 5629   3xhbFPgrYiWY7Oz3qovZuj                                   autumn daze
# 25793  3Ko8zjBg7VtcPTVnd5awJM                            The Christmas Song
# ...                       ...                                           ...
# 25730  43EsFRsE1oBbiVZn9Ewfem            Start Again (feat. Andrea Cormier)
# 28158  6gT6ZGqtaFWnFnuWTVx5us                                   Long Island
# 27095  6DvIcP9qGvYqNAVIdQNj7k                                          Down
# 18406  5GuNH75dVRERmsotXhPAhz                                It's Only Time
# 20021  7LvtI01zEZI0AcKAvPIIUz  Dope's Gotta Hold On Me (feat. Ese Rich Roc)
#
# ...

# %% [markdown]
# 5. Сортировка по возрастанию.

# %%
spotify_songs.sort_values(by='tempo', ascending=False)
# Out:
#                      track_id                                    track_name  \
# 20021  7LvtI01zEZI0AcKAvPIIUz  Dope's Gotta Hold On Me (feat. Ese Rich Roc)
# 18406  5GuNH75dVRERmsotXhPAhz                                It's Only Time
# 27095  6DvIcP9qGvYqNAVIdQNj7k                                          Down
# 28158  6gT6ZGqtaFWnFnuWTVx5us                                   Long Island
# 25730  43EsFRsE1oBbiVZn9Ewfem            Start Again (feat. Andrea Cormier)
# ...                       ...                                           ...
# 25793  3Ko8zjBg7VtcPTVnd5awJM                            The Christmas Song
# 5629   3xhbFPgrYiWY7Oz3qovZuj                                   autumn daze
# 13764  3gIBSlXYIN1mru35l4LWPB             Still Crazy After All These Years
# 1204   6xPVnZ5WcK9sh9FyYIkiW3                                       Knowing
# 11363  51w6nRCU68klqNfYaaVP2j                         Hi, How're You Doin'?
#
# ...

# %% [markdown]
# 5. Сортировка по убыванию.

# %%
spotify_songs.drop([3,4], axis=0, inplace=True)

# %% [markdown]
# 6. Удалили строки 3 и 4.

# %%
import numpy as np
spotify_songs=spotify_songs.replace({"track_artist": "Ed Sheeran"},"NEW")
spotify_songs
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 5      7fvUMiyapMsRRxr07cU8Ef
# 6      2OAylPUDDfwRGfe0lYqlCQ
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name    track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...             NEW
# 1                        Memories - Dillon Francis Remix        Maroon 5
# 2                        All the Time - Don Diablo Remix    Zara Larsson
# 5      Beautiful People (feat. Khalid) - Jack Wins Remix             NEW
# 6                        Never Really Over - R3HAB Remix      Katy Perry
# ...                                                  ...             ...
# 32828               City Of Lights - Official Radio Edit    Lush & Simon
# ...

# %% [markdown]
# 7. Замена значений.

# %%
spotify_songs.drop_duplicates()
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 5      7fvUMiyapMsRRxr07cU8Ef
# 6      2OAylPUDDfwRGfe0lYqlCQ
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name    track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...      Ed Sheeran
# 1                        Memories - Dillon Francis Remix        Maroon 5
# 2                        All the Time - Don Diablo Remix    Zara Larsson
# 5      Beautiful People (feat. Khalid) - Jack Wins Remix      Ed Sheeran
# 6                        Never Really Over - R3HAB Remix      Katy Perry
# ...                                                  ...             ...
# 32828               City Of Lights - Official Radio Edit    Lush & Simon
# ...

# %% [markdown]
# 8. Удаление дубликатов.

# %%
spotify_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32831 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32831 non-null  object
#  1   track_name                32826 non-null  object
#  2   track_artist              32826 non-null  object
#  3   track_popularity          32831 non-null  int64
#  4   track_album_id            32831 non-null  object
#  5   track_album_name          32826 non-null  object
#  6   track_album_release_date  32831 non-null  object
#  7   playlist_name             32831 non-null  object
#  8   playlist_id               32831 non-null  object
#  9   playlist_genre            32831 non-null  object
#  10  playlist_subgenre         32831 non-null  object
#  11  danceability              32831 non-null  float64
#  12  energy                    32831 non-null  float64
# ...

# %% [markdown]
# 9. Анализ с помощью info

# %%
spotify_songs.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32831.000000  32831.000000  32831.000000  32831.000000
# mean          42.475739      0.654848      0.698608      5.374555
# std           24.984219      0.145089      0.180910      3.611676
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32831.000000  32831.000000  32831.000000  32831.000000
# mean      -6.719651      0.565685      0.107070      0.175341
# std        2.988462      0.495674      0.101316      0.219637
# min      -46.448000      0.000000      0.000000      0.000000
# ...

# %% [markdown]
# 10. Анализ с помощью describe.

# %%
subset = spotify_songs.loc[[7, 8, 9], ['track_id', 'track_name', 'track_artist']]
subset
# Out:
#                  track_id                                track_name  \
# 7  6b1RNvAcJjQH73eZO4BLAB  Post Malone (feat. RANI) - GATTÜSO Remix
# 8  7bF6tCO3gFb8INrEDcjNT5    Tough Love - Tiësto Remix / Radio Edit
# 9  1IXGILkPm0tOCNeq00kCPa       If I Can't Have You - Gryffin Remix
#
#    track_artist
# 7     Sam Feldt
# 8        Avicii
# 9  Shawn Mendes

# %% [markdown]
# 11. Выбор определенных строк и столбцов.

# %%
spotify_songs.to_csv("spotify_songs_clear.csv")

# %% [markdown]
# Вывод: мы реализовали базовый анализ датасета:
# Датасеты не повторяются
# Вывели весь датасет и описали его
# Вывели размерноть массива
# Вывели наименование всех колонок, написали что они означают в нашем датасете
# Вывели все уникальные значения
# Отсортировали по определенным параметрам
# Удалили ненужные столбцы или строчки
# Заменили определенные значения в датасете (например, пустые)
# Удалили дубликаты
# Провели анализ с помощью функций info
# Провели анализ с помощью функций describe
# Провели выборку данных по строкам и столбцам с помощью loc
# Сохранили новый датасет
# Сделали вывод по каждому пункту.
